# %%
# %pip install ultralytics
# Out:
# ...
#    ---------------------------------------- 0.0/974.8 kB ? eta -:--:--
#    ----------- ---------------------------- 286.7/974.8 kB 6.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 706.6/974.8 kB 7.5 MB/s eta 0:00:01
#    ---------------------------------------- 974.8/974.8 kB 6.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#     --------------------------------------- 0.6/39.5 MB 19.5 MB/s eta 0:00:02
#    - -------------------------------------- 1.2/39.5 MB 15.4 MB/s eta 0:00:03
#    - -------------------------------------- 1.7/39.5 MB 13.8 MB/s eta 0:00:03
#    -- ------------------------------------- 2.6/39.5 MB 15.2 MB/s eta 0:00:03
#    --- ------------------------------------ 3.5/39.5 MB 16.0 MB/s eta 0:00:03
#    ---- ----------------------------------- 4.3/39.5 MB 16.3 MB/s eta 0:00:03
#    ----- ---------------------------------- 5.3/39.5 MB 17.0 MB/s eta 0:00:03
# ...

# %%
from ultralytics import YOLO

#pretrained model
model = YOLO("yolov8s.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\Brian\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 21.5M/21.5M [00:00<00:00, 32.4MB/s]

# %%
model.info()
# Out:
# YOLOv8s summary: 129 layers, 11,166,560 parameters, 0 gradients, 28.8 GFLOPs
# (129, 11166560, 0, 28.816844800000002)

# %%
model.train(
